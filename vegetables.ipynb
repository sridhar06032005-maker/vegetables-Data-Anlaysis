# %%
Dataset questions:

#Display the first 10 rows of the dataset.

#Find how many rows and columns are present in the dataset.

#Show all column names in the dataset.

#Check the datatype of each column.

2️⃣ Selection & Filtering

#Display only the columns Name, Category, and Color.

#Show all vegetables that belong to the Root category.

#Find all vegetables that are Green in color.

#Display vegetables available only in Summer season.

3️⃣ Conditional Queries

#Find vegetables whose Shelf Life (days) is greater than 30 days.

#Show vegetables whose Origin is South America.

#Display vegetables that require Refrigeration storage.

4️⃣ Sorting

#Sort the dataset by Shelf Life (days) in descending order.

#Sort vegetables alphabetically by Name.

5️⃣ Aggregation (Important for Interview 🔥)

#Count how many vegetables are present in each Category (Root, Leafy, Fruit, etc.).

#Find the average shelf life of vegetables in the dataset.

# %%
import pandas as pd
df=pd.read_csv('d:/vegetables Dataset.csv')
df.head(10)
# Out:
#    Vegetable ID         Name                   Scientific Name Category  \
# 0             1       Carrot                     Daucus carota     Root
# 1             2      Spinach                 Spinacia oleracea    Leafy
# 2             3       Tomato              Solanum lycopersicum    Fruit
# 3             4     Broccoli                 Brassica oleracea   Flower
# 4             5       Potato                 Solanum tuberosum    Tuber
# 5             6  Bell Pepper                   Capsicum annuum    Fruit
# 6             7         Kale  Brassica oleracea var. sabellica    Leafy
# 7             8     Eggplant                 Solanum melongena    Fruit
# 8             9     Zucchini                    Cucurbita pepo    Fruit
# 9            10  Cauliflower   Brassica oleracea var. botrytis   Flower
#
#                 Color       Season           Origin  \
# 0              Orange       Winter      Middle East
# 1               Green  Spring/Fall     Central Asia
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Vegetable ID           Name                 Scientific Name Category  \
# 0               1         Carrot                   Daucus carota     Root
# 1               2        Spinach               Spinacia oleracea    Leafy
# 2               3         Tomato            Solanum lycopersicum    Fruit
# 3               4       Broccoli               Brassica oleracea   Flower
# 4               5         Potato               Solanum tuberosum    Tuber
# ..            ...            ...                             ...      ...
# 145           146  Korean Radish  Raphanus sativus var. koreanus     Root
# 146            47        Chervil           Anthriscus cerefolium     Herb
# 147           148       Amaranth                 Amaranthus spp.    Leafy
# 148           149         Nettle                   Urtica dioica    Leafy
# 149           150            Oca                 Oxalis tuberosa    Tuber
#
# ...

# %%
df.columns
# Out:
# Index(['Vegetable ID', 'Name', 'Scientific Name', 'Category', 'Color',
#        'Season', 'Origin', 'Nutritional Value (per 100g)', 'Price (per kg)',
#        'Availability', 'Shelf Life (days)', 'Storage Requirements',
#        'Growing Conditions', 'Health Benefits', 'Common Varieties'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Vegetable ID                    0
# Name                            0
# Scientific Name                 0
# Category                        0
# Color                           0
# Season                          0
# Origin                          0
# Nutritional Value (per 100g)    0
# Price (per kg)                  0
# Availability                    0
# Shelf Life (days)               0
# Storage Requirements            0
# Growing Conditions              0
# Health Benefits                 0
# Common Varieties                0
# dtype: int64

# %%
rows=df.loc[0]
print(rows)
# Out:
# Vegetable ID                                                     1
# Name                                                        Carrot
# Scientific Name                                      Daucus carota
# Category                                                      Root
# Color                                                       Orange
# Season                                                      Winter
# Origin                                                 Middle East
# Nutritional Value (per 100g)     41 kcal, 0.9g protein, 2.8g fiber
# Price (per kg)                                              $1.50
# Availability                                            Year-round
# Shelf Life (days)                                               30
# Storage Requirements                                 Refrigeration
# Growing Conditions                Well-drained soil, full sunlight
# Health Benefits                 Improves vision, rich in Vitamin A
# ...

# %%
df.columns = [i.lower().replace(' ', '_').replace('/', '_') for i in df.columns]
df.head()
# Out:
#    vegetable_id      name       scientific_name category   color       season  \
# 0             1    Carrot         Daucus carota     Root  Orange       Winter
# 1             2   Spinach     Spinacia oleracea    Leafy   Green  Spring/Fall
# 2             3    Tomato  Solanum lycopersicum    Fruit     Red       Summer
# 3             4  Broccoli     Brassica oleracea   Flower   Green  Fall/Winter
# 4             5    Potato     Solanum tuberosum    Tuber   Brown         Fall
#
#           origin       nutritional_value_(per_100g) price_(per_kg)  \
# 0    Middle East  41 kcal, 0.9g protein, 2.8g fiber         $1.50
# 1   Central Asia  23 kcal, 2.9g protein, 2.2g fiber         $2.00
# 2  South America  18 kcal, 0.9g protein, 1.2g fiber         $3.00
# 3  Mediterranean  34 kcal, 2.8g protein, 2.6g fiber         $2.50
# 4  South America    77 kcal, 2g protein, 2.2g fiber         $1.20
#
#   availability  shelf_life_(days) storage_requirements  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Vegetable ID           Name                 Scientific Name Category  \
# 0               1         Carrot                   Daucus carota     Root
# 1               2        Spinach               Spinacia oleracea    Leafy
# 2               3         Tomato            Solanum lycopersicum    Fruit
# 3               4       Broccoli               Brassica oleracea   Flower
# 4               5         Potato               Solanum tuberosum    Tuber
# ..            ...            ...                             ...      ...
# 145           146  Korean Radish  Raphanus sativus var. koreanus     Root
# 146            47        Chervil           Anthriscus cerefolium     Herb
# 147           148       Amaranth                 Amaranthus spp.    Leafy
# 148           149         Nettle                   Urtica dioica    Leafy
# 149           150            Oca                 Oxalis tuberosa    Tuber
#
# ...

# %%
df.dtypes
# Out:
# vegetable_id                     int64
# name                            object
# scientific_name                 object
# category                        object
# color                           object
# season                          object
# origin                          object
# nutritional_value_(per_100g)    object
# price_(per_kg)                  object
# availability                    object
# shelf_life_(days)                int64
# storage_requirements            object
# growing_conditions              object
# health_benefits                 object
# common_varieties                object
# dtype: object

# %%
df.columns
# Out:
# Index(['vegetable_id', 'name', 'scientific_name', 'category', 'color',
#        'season', 'origin', 'nutritional_value_(per_100g)', 'price_(per_kg)',
#        'availability', 'shelf_life_(days)', 'storage_requirements',
#        'growing_conditions', 'health_benefits', 'common_varieties'],
#       dtype='object')

# %%
df[['name', 'category', 'color']]
# Out:
#               name category        color
# 0           Carrot     Root       Orange
# 1          Spinach    Leafy        Green
# 2           Tomato    Fruit          Red
# 3         Broccoli   Flower        Green
# 4           Potato    Tuber        Brown
# ..             ...      ...          ...
# 145  Korean Radish     Root        White
# 146        Chervil     Herb        Green
# 147       Amaranth    Leafy   Green, Red
# 148         Nettle    Leafy        Green
# 149            Oca    Tuber  Red, Yellow
#
# [150 rows x 3 columns]

# %%
df[df['category'] == 'Root']
# Out:
#      vegetable_id           name                      scientific_name  \
# 0               1         Carrot                        Daucus carota
# 16             17       Beetroot                        Beta vulgaris
# 17             18         Radish                     Raphanus sativus
# 25             26         Turnip                        Brassica rapa
# 33             34        Parsnip                     Pastinaca sativa
# 36             37       Rutabaga     Brassica napus var. napobrassica
# 37             38       Kohlrabi    Brassica oleracea var. gongylodes
# 38             39         Jicama                   Pachyrhizus erosus
# 48             49  Daikon Radish  Raphanus sativus var. longipinnatus
# 56             57       Kohlrabi    Brassica oleracea var. gongylodes
# 57             58       Celeriac       Apium graveolens var. rapaceum
# 58             59        Salsify               Tragopogon porrifolius
# ...

# %%
df[df['color'] == 'Green']
# Out:
#      vegetable_id            name        scientific_name category  color  \
# 1               2         Spinach      Spinacia oleracea    Leafy  Green
# 3               4        Broccoli      Brassica oleracea   Flower  Green
# 8               9        Zucchini         Cucurbita pepo    Fruit  Green
# 12             13     Green Beans     Phaseolus vulgaris   Legume  Green
# 15             16         Lettuce         Lactuca sativa    Leafy  Green
# ..            ...             ...                    ...      ...    ...
# 142           143      Land Cress      Barbarea vulgaris    Leafy  Green
# 143           144  Poblano Pepper        Capsicum annuum    Fruit  Green
# 144           145         Chayote          Sechium edule    Fruit  Green
# 146            47         Chervil  Anthriscus cerefolium     Herb  Green
# 148           149          Nettle          Urtica dioica    Leafy  Green
#
#             season           origin       nutritional_value_(per_100g)  \
# ...

# %%
df[df['season'] == 'Summer']
# Out:
#      vegetable_id                 name  \
# 2               3               Tomato
# 5               6          Bell Pepper
# 7               8             Eggplant
# 8               9             Zucchini
# 12             13          Green Beans
# 13             14                Onion
# 20             21                 Corn
# 22             23             Cucumber
# 26             27                 Okra
# 38             39               Jicama
# 41             42              Chayote
# 45             46            Tomatillo
# 49             50         Bitter Melon
# 54             55             Purslane
# 61             62      Amaranth Greens
# 63             64              Tindora
# 64             65      Malabar Spinach
# 66             67          Winged Bean
# 67             68          Snake Gourd
# 72             73        Yardlong Bean
# 76             77             Samphire
# 77             78              Tindora
# 82             83  Sweet Potato Leaves
# ...

# %%
df[df['shelf_life_(days)'] > 30]
# Out:
#     vegetable_id     name    scientific_name category               color  \
# 4              5   Potato  Solanum tuberosum    Tuber               Brown
# 13            14    Onion        Allium cepa     Bulb  Yellow, Red, White
# 14            15   Garlic     Allium sativum     Bulb               White
# 18            19  Pumpkin     Cucurbita pepo    Fruit              Orange
#
#     season         origin        nutritional_value_(per_100g) price_(per_kg)  \
# 4     Fall  South America     77 kcal, 2g protein, 2.2g fiber         $1.20
# 13  Summer   Central Asia   40 kcal, 1.1g protein, 1.7g fiber         $1.20
# 14    Fall   Central Asia  149 kcal, 6.4g protein, 2.1g fiber         $5.00
# 18    Fall  North America     26 kcal, 1g protein, 0.5g fiber         $1.20
#
#    availability  shelf_life_(days) storage_requirements  \
# 4    Year-round                 60     Cool, dark place
# 13   Year-round                 60      Cool, dry place
# ...

# %%
df[df['origin'] == 'South America']
# Out:
#      vegetable_id         name       scientific_name category          color  \
# 2               3       Tomato  Solanum lycopersicum    Fruit            Red
# 4               5       Potato     Solanum tuberosum    Tuber          Brown
# 12             13  Green Beans    Phaseolus vulgaris   Legume          Green
# 51             52      Cassava     Manihot esculenta    Tuber          Brown
# 83             84          Oca       Oxalis tuberosa    Tuber   Orange, Pink
# 95             96          Oca       Oxalis tuberosa    Tuber   Orange, Pink
# 99            100      Cassava     Manihot esculenta    Tuber          Brown
# 137           138   Nasturtium      Tropaeolum majus    Leafy  Green, Orange
#
#          season         origin        nutritional_value_(per_100g)  \
# 2        Summer  South America   18 kcal, 0.9g protein, 1.2g fiber
# 4          Fall  South America     77 kcal, 2g protein, 2.2g fiber
# 12       Summer  South America   31 kcal, 1.8g protein, 2.7g fiber
# ...

# %%
df[df['storage_requirements'] == 'Refrigeration']
# Out:
#      vegetable_id            name                   scientific_name category  \
# 0               1          Carrot                     Daucus carota     Root
# 1               2         Spinach                 Spinacia oleracea    Leafy
# 3               4        Broccoli                 Brassica oleracea   Flower
# 5               6     Bell Pepper                   Capsicum annuum    Fruit
# 6               7            Kale  Brassica oleracea var. sabellica    Leafy
# ..            ...             ...                               ...      ...
# 143           144  Poblano Pepper                   Capsicum annuum    Fruit
# 145           146   Korean Radish    Raphanus sativus var. koreanus     Root
# 146            47         Chervil             Anthriscus cerefolium     Herb
# 147           148        Amaranth                   Amaranthus spp.    Leafy
# 148           149          Nettle                     Urtica dioica    Leafy
#
# ...

# %%
df.sort_values(by='shelf_life_(days)', ascending=False)
# Out:
#      vegetable_id              name        scientific_name category  \
# 14             15            Garlic         Allium sativum     Bulb
# 4               5            Potato      Solanum tuberosum    Tuber
# 13             14             Onion            Allium cepa     Bulb
# 18             19           Pumpkin         Cucurbita pepo    Fruit
# 11             12      Sweet Potato        Ipomoea batatas    Tuber
# ..            ...               ...                    ...      ...
# 113           114           Chervil  Anthriscus cerefolium     Herb
# 133           134            Sorrel          Rumex acetosa    Leafy
# 132           133  Dandelion Greens   Taraxacum officinale    Leafy
# 146            47           Chervil  Anthriscus cerefolium     Herb
# 148           149            Nettle          Urtica dioica    Leafy
#
#                   color         season           origin  \
# 14                White           Fall     Central Asia
# ...

# %%
df.sort_values(by='Name')
# Out:
#      Vegetable ID             Name                         Scientific Name  \
# 47             48     Acorn Squash           Cucurbita pepo var. turbinata
# 147           148         Amaranth                         Amaranthus spp.
# 87             88         Amaranth                         Amaranthus spp.
# 61             62  Amaranth Greens                         Amaranthus spp.
# 29             30        Artichoke                         Cynara scolymus
# ..            ...              ...                                     ...
# 66             67      Winged Bean             Psophocarpus tetragonolobus
# 72             73    Yardlong Bean  Vigna unguiculata subsp. sesquipedalis
# 124           125           Yarrow                    Achillea millefolium
# 126           127    Yellow Squash                          Cucurbita pepo
# 8               9         Zucchini                          Cucurbita pepo
#
#     Category          Color  Season           Origin  \
# ...

# %%
df['category'].value_counts()
# Out:
# category
# Leafy        50
# Root         25
# Fruit        22
# Tuber        18
# Bulb          7
# Flower        6
# Stem          6
# Herb          6
# Legume        4
# Cactus        3
# Grain         1
# Succulent     1
# Fern          1
# Name: count, dtype: int64

# %%
df.groupby('category')['name'].count()
# Out:
# category
# Bulb          7
# Cactus        3
# Fern          1
# Flower        6
# Fruit        22
# Grain         1
# Herb          6
# Leafy        50
# Legume        4
# Root         25
# Stem          6
# Succulent     1
# Tuber        18
# Name: name, dtype: int64

# %%
df['shelf_life_(days)'].mean()
# Out:
# np.float64(13.006666666666666)

# %%
df.groupby('category')['shelf_life_(days)'].mean()
# Out:
# category
# Bulb         32.428571
# Cactus        8.000000
# Fern          5.000000
# Flower        9.000000
# Fruit        12.727273
# Grain         7.000000
# Herb          6.000000
# Leafy         7.240000
# Legume        6.500000
# Root         17.880000
# Stem          9.166667
# Succulent     5.000000
# Tuber        23.500000
# Name: shelf_life_(days), dtype: float64

# %%
df.to_csv('D:/cleaned data vegetables.csv',index=False)

# %%
import mysql.connector
import pandas as pd
cn=mysql.connector.connect(host="127.0.0.1",user="root",password="SrIdHaR",database="vegetables")
q="SELECT * FROM vegies"
df=pd.read_sql(q,cn) 
print(df)
# Out:
#      vegetable_id           name                 scientific_name category  \
# 0               1         Carrot                   Daucus carota     Root
# 1               2        Spinach               Spinacia oleracea    Leafy
# 2               3         Tomato            Solanum lycopersicum    Fruit
# 3               4       Broccoli               Brassica oleracea   Flower
# 4               5         Potato               Solanum tuberosum    Tuber
# ..            ...            ...                             ...      ...
# 145           146  Korean Radish  Raphanus sativus var. koreanus     Root
# 146            47        Chervil           Anthriscus cerefolium     Herb
# 147           148       Amaranth                 Amaranthus spp.    Leafy
# 148           149         Nettle                   Urtica dioica    Leafy
# 149           150            Oca                 Oxalis tuberosa    Tuber
#
#            color         season         origin  \
# ...
